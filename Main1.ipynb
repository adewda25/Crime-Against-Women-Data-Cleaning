# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:/PPBI PROJECT/Data/Raw/Victims_of_rape.csv")

# %%
df
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
df.shape
#check how many and columns in the data
# Out:
# (1050, 11)

# %%
df.info()
#check data types
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Area_Name                  1050 non-null   str
#  1   Year                       1050 non-null   int64
#  2   Subgroup                   1050 non-null   str
#  3   Rape_Cases_Reported        1050 non-null   int64
#  4   Victims_Above_50_Yrs       1050 non-null   int64
#  5   Victims_Between_10-14_Yrs  1050 non-null   int64
#  6   Victims_Between_14-18_Yrs  1050 non-null   int64
#  7   Victims_Between_18-30_Yrs  1050 non-null   int64
#  8   Victims_Between_30-50_Yrs  1050 non-null   int64
#  9   Victims_of_Rape_Total      1050 non-null   int64
#  10  Victims_Upto_10_Yrs        1050 non-null   int64
# dtypes: int64(9), str(2)
# memory usage: 90.4 KB

# %%
df.isnull().sum()
#check null values
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
df.duplicated().sum()
#count duplicates rows
# Out:
# np.int64(0)

# %%
df.columns =df.columns.str.strip()
#removing extra spaces

# %%
df= df.rename(columns = {
    'Area_Name' :'State',
    'Sub_group' : 'Sub_Group',
    'Rape_Cases_Reported' : 'Cases_Reported',
    'Victims_of_Rape_Total' : 'Total_Victims'
})

# %%
df['Sub_Group'].unique()
#find cateogries
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\PPBI PROJECT\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
df['Victim_Percentage'] = (
    df['Total_Victims'] /
    df['Total_Victims'].sum()
) * 100

# %%
State_Data = df.groupby('State') ['Total_Victims'].sum()
#state by grouping of victims
#Identify the top crime state

# %%
Year_Data = df.groupby('Year') ['Total_Victims'].sum()
#Crime Trend analysis

# %%
df.dtypes
# Out:
# State                            str
# Year                           int64
# Sub_Group                        str
# Cases_Reported                 int64
# Victims_Above_50_Yrs           int64
# Victims_Between_10-14_Yrs      int64
# Victims_Between_14-18_Yrs      int64
# Victims_Between_18-30_Yrs      int64
# Victims_Between_30-50_Yrs      int64
# Total_Victims                  int64
# Victims_Upto_10_Yrs            int64
# Victim_Percentage            float64
# dtype: object

# %%
df['Year'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Sub_Group', 'Cases_Reported', 'Victims_Above_50_Yrs',
#        'Victims_Between_10-14_Yrs', 'Victims_Between_14-18_Yrs',
#        'Victims_Between_18-30_Yrs', 'Victims_Between_30-50_Yrs',
#        'Total_Victims', 'Victims_Upto_10_Yrs', 'Victim_Percentage'],
#       dtype='str')

# %%
(
    df['Victims_Upto_10_Yrs'] +
    df['Victims_Between_10-14_Yrs'] +
    df['Victims_Between_14-18_Yrs'] +
    df['Victims_Between_18-30_Yrs'] +
    df['Victims_Between_30-50_Yrs'] +
    df['Victims_Above_50_Yrs']
).equals(df['Total_Victims'])
# Out:
# True

# %%
df.describe()
# Out:
#              Year  Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000     1050.000000           1050.000000
# mean   2005.50000      361.920000              1.866667
# std       2.87365      592.180572              4.640286
# min    2001.00000        0.000000              0.000000
# 25%    2003.00000        4.000000              0.000000
# 50%    2005.50000       37.000000              0.000000
# 75%    2008.00000      527.500000              1.000000
# max    2010.00000     3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     3.000000                   5.000000
# ...

# %%
df.to_csv("clean_victims_data.csv", index=False)

# %%
df
# Out:
#                           State  Year                Subgroup  Cases_Reported  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims               3
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape               1
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape               2
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims               2
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape               0
# ...                         ...   ...                     ...             ...
# 1045                West Bengal  2009  Victims of Incest Rape               3
# 1046                West Bengal  2009   Victims of Other Rape            2333
# 1047                West Bengal  2010      Total Rape Victims            2311
# 1048                West Bengal  2010  Victims of Incest Rape               4
# 1049                West Bengal  2010   Victims of Other Rape            2307
#
# ...
