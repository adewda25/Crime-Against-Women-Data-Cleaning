# %%
import pandas as pd

# %%
Victims_df= pd.read_csv(r'D:/PPBI PROJECT\Data/Procceed/clean_victims_data.csv')
Arrest_df= pd.read_csv(r'D:/PPBI PROJECT\Data/Procceed/cleaned_Arrest.csv')
Crime_df= pd.read_csv(r'D:/PPBI PROJECT\Data/Procceed/cleaned_crime_against_women.csv')
Kidnapping_df= pd.read_csv(r'D:/PPBI PROJECT\Data/Procceed/kidnapping_data.csv')

# %%
print(Crime_df.columns)
print(Arrest_df.columns)
print(Victims_df.columns)
print(Kidnapping_df.columns)
# Out:
# Index(['State', 'Year', 'Group_Name', 'Sub_Group_Name', 'Cases_Acquitted',
#        'Cases_Chargesheeted', 'Cases_Convicted', 'Pending_Investigation_End',
#        'Pending_Trial_End', 'Cases_Reported', 'Cases_Sent_for_Trial',
#        'Trials_Completed', 'Total_Cases_for_Trial'],
#       dtype='str')
# Index(['State', 'Year', 'Group_Name', 'Sub_Group', 'Acquitted', 'Withdrawn',
#        'Arrested', 'Chargesheeted', 'Convicted', 'Released_Before_Trial',
#        'Trial_Completed', 'Persons_Under_Trial_At_Year_Beginning',
#        'Total_Persons_Under_Trial', 'High_Crime_Area'],
#       dtype='str')
# Index(['State', 'Year', 'Sub_Group', 'Cases_Reported', 'Victims_Above_50_Yrs',
#        'Victims_Between_10-14_Yrs', 'Victims_Between_14-18_Yrs',
#        'Victims_Between_18-30_Yrs', 'Victims_Between_30-50_Yrs',
#        'Total_Victims', 'Victims_Upto_10_Yrs'],
#       dtype='str')
# Index(['State', 'Year', 'Group_Name', 'Subgroup_Name', 'Cases_Reported',
# ...

# %%
print(Crime_df.shape)
print(Arrest_df.shape)
print(Victims_df.shape)
print(Kidnapping_df.shape)
# Out:
# (4165, 13)
# (4165, 14)
# (1050, 11)
# (3202, 9)
