# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"D:/PPBI PROJECT/Data/Procceed/clean_victims_data.csv")
df2 = pd.read_csv(r"D:/PPBI PROJECT/Data/Procceed/cleaned_Arrest_crime_against_women.csv")
df3 = pd.read_csv(r"D:/PPBI PROJECT/Data/Procceed/cleaned_crime_against_women.csv")
df4 = pd.read_csv(r"D:/PPBI PROJECT/Data/Procceed/kidnapping_data.csv")

# %%
df1.head(5)
# Out:
#                        State  Year               Sub_Group  Cases_Reported  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims               3
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape               1
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape               2
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims               2
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape               0
#
#    Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                     0                          0                          3
# 1                     0                          0                          1
# 2                     0                          0                          2
# 3                     0                          0                          1
# 4                     0                          0                          0
#
# ...

# %%
df2.head(5)
# Out:
#                        State  Year Group_Name Sub_Group  Acquitted  Withdrawn  \
# 0  Andaman & Nicobar Islands  2001       Rape  01. Rape          6          0
# 1             Andhra Pradesh  2001       Rape  01. Rape       1168         13
# 2          Arunachal Pradesh  2001       Rape  01. Rape          1          0
# 3                      Assam  2001       Rape  01. Rape        403         14
# 4                      Bihar  2001       Rape  01. Rape        756          0
#
#    Arrested  Chargesheeted  Convicted  Released_Before_Trial  Trial_Completed  \
# 0         3              3          0                      0                6
# 1      1150           1021        246                     34             1414
# 2        51             31          2                     15                3
# 3       928            585        120                    190              523
# 4      1400           1302        217                    241              973
#
# ...

# %%
df3.head(5)
# Out:
#                        State  Year Group_Name Sub_Group_Name  Cases_Acquitted  \
# 0  Andaman & Nicobar Islands  2001       Rape       01. Rape                5
# 1             Andhra Pradesh  2001       Rape       01. Rape              731
# 2          Arunachal Pradesh  2001       Rape       01. Rape                1
# 3                      Assam  2001       Rape       01. Rape              334
# 4                      Bihar  2001       Rape       01. Rape              406
#
#    Cases_Chargesheeted  Cases_Convicted  Pending_Investigation_End  \
# 0                    3                0                          1
# 1                  769              197                        393
# 2                   25                2                         18
# 3                  495              101                       1045
# 4                  685              155                        488
#
#    Pending_Trial_End  Cases_Reported  Cases_Sent_for_Trial  Trials_Completed  \
# ...

# %%
df4.head(5)
# Out:
#                State  Year             Group_Name     Subgroup_Name  \
# 0     Andhra Pradesh  2001  Kidnap - For Adoption  01. For Adoption
# 1  Arunachal Pradesh  2001  Kidnap - For Adoption  01. For Adoption
# 2              Assam  2001  Kidnap - For Adoption  01. For Adoption
# 3              Bihar  2001  Kidnap - For Adoption  01. For Adoption
# 4         Chandigarh  2001  Kidnap - For Adoption  01. For Adoption
#
#    Cases_Reported  Female_Total  Total_Cases  Male_Total  Gender_Gap
# 0               8             5            8           3           2
# 1               0             0            0           0           0
# 2               0             0            0           0           0
# 3              18             0           18          18         -18
# 4               0             0            0           0           0

# %%
merged_df = pd.merge(
    df1,df2,
    on = ['State','Year'],
    how = 'inner'
)
print(merged_df.head())
# Out:
#                        State  Year         Sub_Group_x  Cases_Reported  \
# 0  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 1  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 2  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 3  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 4  Andaman & Nicobar Islands  2001  Total Rape Victims               3
#
#    Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                     0                          0                          3
# 1                     0                          0                          3
# 2                     0                          0                          3
# 3                     0                          0                          3
# 4                     0                          0                          3
#
# ...

# %%
merged_df.head(5)
# Out:
#                        State  Year         Sub_Group_x  Cases_Reported  \
# 0  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 1  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 2  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 3  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 4  Andaman & Nicobar Islands  2001  Total Rape Victims               3
#
#    Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                     0                          0                          3
# 1                     0                          0                          3
# 2                     0                          0                          3
# 3                     0                          0                          3
# 4                     0                          0                          3
#
# ...

# %%
print(merged_df.isnull().sum())
# Out:
# State                                    0
# Year                                     0
# Sub_Group_x                              0
# Cases_Reported                           0
# Victims_Above_50_Yrs                     0
# Victims_Between_10-14_Yrs                0
# Victims_Between_14-18_Yrs                0
# Victims_Between_18-30_Yrs                0
# Victims_Between_30-50_Yrs                0
# Total_Victims                            0
# Victims_Upto_10_Yrs                      0
# Group_Name                               0
# Sub_Group_y                              0
# Acquitted                                0
# Withdrawn                                0
# Arrested                                 0
# Chargesheeted                            0
# Convicted                                0
# Released_Before_Trial                    0
# Trial_Completed                          0
# Persons_Under_Trial_At_Year_Beginning    0
# Total_Persons_Under_Trial                0
# ...

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged_df.describe()
# Out:
#                Year  Cases_Reported  Victims_Above_50_Yrs  \
# count  12495.000000    12495.000000          12495.000000
# mean    2005.478992      361.525250              1.860584
# std        2.875244      591.349361              4.630281
# min     2001.000000        0.000000              0.000000
# 25%     2003.000000        4.000000              0.000000
# 50%     2005.000000       37.000000              0.000000
# 75%     2008.000000      529.000000              1.000000
# max     2010.000000     3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count               12495.000000               12495.000000
# mean                   23.642897                  52.972229
# std                    50.684184                 114.810127
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     3.000000                   5.000000
# ...

# %%
(merged_df['Sub_Group_x'] == merged_df['Sub_Group_y']).sum()
# Out:
# np.int64(0)

# %%
(merged_df['Sub_Group_x'] == merged_df['Sub_Group_y']).all()
# Out:
# np.False_

# %%
merged_df[['Sub_Group_x','Sub_Group_y']].isnull().sum()
# Out:
# Sub_Group_x    0
# Sub_Group_y    0
# dtype: int64

# %%
merged_df[
    merged_df['Sub_Group_x'].isna() |
    merged_df['Sub_Group_y'].isna()
][['Sub_Group_x','Sub_Group_y']].head()
# Out:
# Empty DataFrame
# Columns: [Sub_Group_x, Sub_Group_y]
# Index: []

# %%
merged_df['Sub_Group_x'].fillna('Missing').equals(
    merged_df['Sub_Group_y'].fillna('Missing')
)
# Out:
# False

# %%
print(merged_df['Sub_Group_x'].nunique())
print(merged_df['Sub_Group_y'].nunique())
# Out:
# 3
# 12

# %%
df1.columns
# Out:
# Index(['State', 'Year', 'Sub_Group', 'Cases_Reported', 'Victims_Above_50_Yrs',
#        'Victims_Between_10-14_Yrs', 'Victims_Between_14-18_Yrs',
#        'Victims_Between_18-30_Yrs', 'Victims_Between_30-50_Yrs',
#        'Total_Victims', 'Victims_Upto_10_Yrs'],
#       dtype='str')

# %%
df2.columns
# Out:
# Index(['State', 'Year', 'Group_Name', 'Sub_Group', 'Acquitted', 'Withdrawn',
#        'Arrested', 'Chargesheeted', 'Convicted', 'Released_Before_Trial',
#        'Trial_Completed', 'Persons_Under_Trial_At_Year_Beginning',
#        'Total_Persons_Under_Trial', 'High_Crime_Area'],
#       dtype='str')

# %%
df1.shape
# Out:
# (1050, 11)

# %%
merged_df.shape
# Out:
# (12495, 23)

# %%
df2.shape
# Out:
# (4165, 14)

# %%
df1[['State','Year']].duplicated().sum()
# Out:
# np.int64(700)

# %%
df2[['State','Year']].duplicated().sum()
# Out:
# np.int64(3815)

# %%
df1.to_csv("d1 and d2_data.csv", index=False)

# %%
merged_df2 = pd.merge(
    df3,df4,
    on = ['State','Year'],
    how = 'inner'
)
print(merged_df.head())
# Out:
#                        State  Year         Sub_Group_x  Cases_Reported  \
# 0  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 1  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 2  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 3  Andaman & Nicobar Islands  2001  Total Rape Victims               3
# 4  Andaman & Nicobar Islands  2001  Total Rape Victims               3
#
#    Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                     0                          0                          3
# 1                     0                          0                          3
# 2                     0                          0                          3
# 3                     0                          0                          3
# 4                     0                          0                          3
#
# ...

# %%
merged_df2
# Out:
#                 State  Year               Group_Name_x  \
# 0      Andhra Pradesh  2001                       Rape
# 1      Andhra Pradesh  2001                       Rape
# 2      Andhra Pradesh  2001                       Rape
# 3      Andhra Pradesh  2001                       Rape
# 4      Andhra Pradesh  2001                       Rape
# ...               ...   ...                        ...
# 38093     West Bengal  2010  Total Crime Against Women
# 38094     West Bengal  2010  Total Crime Against Women
# 38095     West Bengal  2010  Total Crime Against Women
# 38096     West Bengal  2010  Total Crime Against Women
# 38097     West Bengal  2010  Total Crime Against Women
#
#                        Sub_Group_Name  Cases_Acquitted  Cases_Chargesheeted  \
# 0                            01. Rape              731                  769
# 1                            01. Rape              731                  769
# ...

# %%
merged_df.isnull().sum()
# Out:
# State                                    0
# Year                                     0
# Sub_Group_x                              0
# Cases_Reported                           0
# Victims_Above_50_Yrs                     0
# Victims_Between_10-14_Yrs                0
# Victims_Between_14-18_Yrs                0
# Victims_Between_18-30_Yrs                0
# Victims_Between_30-50_Yrs                0
# Total_Victims                            0
# Victims_Upto_10_Yrs                      0
# Group_Name                               0
# Sub_Group_y                              0
# Acquitted                                0
# Withdrawn                                0
# Arrested                                 0
# Chargesheeted                            0
# Convicted                                0
# Released_Before_Trial                    0
# Trial_Completed                          0
# Persons_Under_Trial_At_Year_Beginning    0
# Total_Persons_Under_Trial                0
# ...

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(0)
